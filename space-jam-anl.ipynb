# %%
pip install jupyter
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting jupyter
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting notebook
#   Using cached notebook-6.4.10-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: ipykernel in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jupyter) (5.5.6)
# Collecting nbconvert
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting qtconsole
#   Using cached qtconsole-5.2.2-py3-none-any.whl (120 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.4.3-py3-none-any.whl (22 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-7.8.1-py2.py3-none-any.whl (124 kB)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipykernel->jupyter) (7.16.3)
# Requirement already satisfied: tornado>=4.2 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: ipython-genutils in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipykernel->jupyter) (4.3.3)
# Requirement already satisfied: jupyter-client in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipykernel->jupyter) (7.1.2)
# Collecting comm>=0.1.3
#   Using cached comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting widgetsnbextension~=3.6.6
#   Using cached widgetsnbextension-3.6.6-py2.py3-none-any.whl (1.6 MB)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Using cached jupyterlab_widgets-1.1.7-py3-none-any.whl (295 kB)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jupyter-console->jupyter) (3.0.36)
# Requirement already satisfied: pygments in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jupyter-console->jupyter) (2.14.0)
# Collecting nbformat>=4.4
#   Using cached nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting bleach
#   Using cached bleach-4.1.0-py2.py3-none-any.whl (157 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: jupyter-core in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from nbconvert->jupyter) (4.9.2)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting jinja2>=2.4
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Using cached nbclient-0.5.9-py3-none-any.whl (69 kB)
# Collecting testpath
#   Using cached testpath-0.6.0-py3-none-any.whl (83 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from notebook->jupyter) (1.6.0)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.12.1-py3-none-any.whl (15 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.17.1-py3-none-any.whl (60 kB)
# Requirement already satisfied: pyzmq>=17 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from notebook->jupyter) (25.1.2)
# Collecting qtpy
#   Using cached QtPy-2.0.1-py3-none-any.whl (65 kB)
# Requirement already satisfied: backcall in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: jedi<=0.17.2,>=0.10 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.17.2)
# Requirement already satisfied: colorama in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.4.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (28.8.0)
# Requirement already satisfied: decorator in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter) (5.1.1)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.0.1-cp36-cp36m-win32.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jupyter-client->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jupyter-core->nbconvert->jupyter) (305)
# Collecting async-generator
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: wcwidth in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.13)
# Collecting pywinpty>=1.1.0
#   Using cached pywinpty-2.0.3.tar.gz (23 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-2.0.2.tar.gz (22 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-2.0.1.tar.gz (22 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.6.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.5.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.4.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.3.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.2.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.1.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   Using cached pywinpty-1.1.0.tar.gz (48 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Collecting terminado>=0.8.3
#   Using cached terminado-0.12.0-py3-none-any.whl (15 kB)
#   Using cached terminado-0.11.1-py3-none-any.whl (15 kB)
#   Using cached terminado-0.11.0-py3-none-any.whl (15 kB)
#   Using cached terminado-0.10.1-py3-none-any.whl (14 kB)
#   Using cached terminado-0.10.0-py3-none-any.whl (14 kB)
#   Using cached terminado-0.9.5-py3-none-any.whl (14 kB)
# Collecting pywinpty<1,>=0.5
#   Using cached pywinpty-0.5.7-cp36-cp36m-win32.whl (1.3 MB)
# Requirement already satisfied: six in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter) (1.16.0)
# Collecting typing-extensions
#   Using cached typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting dataclasses
#   Using cached dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win32.whl (27 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting packaging
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from jedi<=0.17.2,>=0.10->ipython>=5.0.0->ipykernel->jupyter) (0.7.1)
# Collecting importlib-metadata
#   Using cached importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Collecting pyrsistent>=0.14.0
#   Using cached pyrsistent-0.18.0-cp36-cp36m-win32.whl (59 kB)
# Collecting attrs>=17.4.0
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp36-cp36m-win32.whl (174 kB)
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Using cached pyparsing-3.0.7-py3-none-any.whl (98 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Installing collected packages: zipp, typing-extensions, pyrsistent, importlib-metadata, attrs, pyparsing, pycparser, jsonschema, webencodings, packaging, nbformat, MarkupSafe, cffi, async-generator, testpath, pywinpty, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, defusedxml, dataclasses, bleach, argon2-cffi-bindings, terminado, Send2Trash, prometheus-client, nbconvert, argon2-cffi, notebook, widgetsnbextension, qtpy, jupyterlab-widgets, comm, qtconsole, jupyter-console, ipywidgets, jupyter
# Successfully installed MarkupSafe-2.0.1 Send2Trash-1.8.3 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0
(from https://pypi.org/simple/pywinpty/) (requires-python:>=3.6). Command errored out with exit status 1: 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\Scripts\python.exe' 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\kacpe\AppData\Local\Temp\tmphqg5h7q7' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\Scripts\python.exe' 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\kacpe\AppData\Local\Temp\tmpfknrva_k'
#        cwd: C:\Users\kacpe\AppData\Local\Temp\pip-install-ctxkuygv\pywinpty_2f77be4ecfd241f1a7f49b8e668210c8
#   Complete output (6 lines):
#   Checking for Rust toolchain....
#
#   Cargo, the Rust package manager, is not installed or is not on PATH.
#   This package requires Rust and Cargo to compile extensions. Install it through
#   the system's package manager or via https://rustup.rs/
#
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/40/ed/694e4a642e3b8afac6d6e70538a3684e1049f2020a33002b58e1ac5cd4b3/pywinpty-1.1.1.tar.gz#sha256=4a3ffa2444daf15c5f65a76b5b2864447cc915564e41e2876816b9e4fe849070 (from https://pypi.org/simple/pywinpty/) (requires-python:>=3.6). Command errored out with exit status 1: 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\Scripts\python.exe' 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\kacpe\AppData\Local\Temp\tmpfknrva_k' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\Scripts\python.exe' 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\kacpe\AppData\Local\Temp\tmp3rqsxl4z'
#        cwd: C:\Users\kacpe\AppData\Local\Temp\pip-install-ctxkuygv\pywinpty_1418c99e1de644cbb6e40395593ad12a
#   Complete output (6 lines):
#   Checking for Rust toolchain....
#
#   Cargo, the Rust package manager, is not installed or is not on PATH.
#   This package requires Rust and Cargo to compile extensions. Install it through
#   the system's package manager or via https://rustup.rs/
#
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/02/aeb98dc7ac48e3fc6ba13159be5c6fbd0d19e2d11edf996e96d031fa86ca/pywinpty-1.1.0.tar.gz#sha256=f60ed4947fe0841e7d7cafae4885a0040d4994a4647dd21be4ed4266789885c9 (from https://pypi.org/simple/pywinpty/). Command errored out with exit status 1: 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\Scripts\python.exe' 'c:\Users\kacpe\Downloads\space-jam-anl\.venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\kacpe\AppData\Local\Temp\tmp3rqsxl4z' Check the logs for full command output.

# %%
pip install jupyter
# Out:
# Running cells with 'Python 3.6.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/kacpe/AppData/Local/Programs/Python/Python36-32/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pip install -U ipykernel
# Out:
# Running cells with 'Python 3.6.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/kacpe/AppData/Local/Programs/Python/Python36-32/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.1.5-cp36-cp36m-win32.whl (7.8 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2017.2
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting numpy>=1.15.4
#   Using cached numpy-1.19.5-cp36-cp36m-win32.whl (11.0 MB)
# Requirement already satisfied: six>=1.5 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.19.5 pandas-1.1.5 pytz-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# Import the CSV file and create a DataFrame.
player_df_final = pd.read_csv('player_data_final.csv')

# %%
# Create a DataFrame of only Tune Squad players.
ts_df = player_df_final.iloc[26: , :]
ts_df
# Out:
#     ID        player  points  possessions  team_pace         GP        MPG  \
# 26  31   tune_squad1  2049.0       1434.0      110.0  64.000000  38.800000
# 27  32   tune_squad2  1795.0       1481.8      112.1  62.000000  35.400000
# 28  33   tune_squad3  1805.0       1509.9      108.6  64.000000  35.400000
# 29  34   tune_squad4  1743.0       1422.4      112.9  64.000000  36.300000
# 30  35   tune_squad5  1963.0       1539.1      117.4  59.771429  35.208333
# 31  36   tune_squad6  2062.0       1505.7      111.5  59.771429  37.000000
# 32  37   tune_squad7  1845.0       1435.7      113.1  69.000000  36.900000
# 33  38   tune_squad8  1778.0       1526.4      109.3  66.000000  34.900000
# 34  39   tune_squad9  1901.0       1444.1      109.7  67.000000  36.500000
# 35  41  tune_squad11  2030.0       1431.0      112.3  68.000000  37.000000
# 36  42  tune_squad12  1631.0       1465.7      110.1  66.000000  37.500000
# 37  43  tune_squad13  1828.0       1507.2      112.7  64.000000  36.500000
# 38  44  tune_squad14  1821.0       1443.7      118.8  66.000000  36.600000
# 39  45  tune_squad15  1740.0       1443.9      114.1  68.000000  37.100000
# 40  46  tune_squad16  1993.0       1459.0      112.5  59.771429  36.900000
#
#       TS%   AST    TO   USG  ORR   DRR  REBR        PER
# 26  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000
# 27  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000
# 28  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000
# 29  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138
# 30  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000
# 31  0.620  29.8  15.6  36.2  4.9  23.9  14.7  27.860000
# 32  0.634  33.2  14.0  36.5  4.1  21.5  16.4  34.260000
# 33  0.612  30.6  15.9  35.9  5.5  18.8  13.7  28.650000
# 34  0.609  27.2  14.8  35.5  5.0  21.8   8.9  20.120000
# 35  0.618  32.5  15.3  34.5  5.7  15.7  13.2  30.070000
# 36  0.613  28.4  14.4  35.7  6.5  20.7  14.0  28.400000
# 37  0.618  31.3  14.0  34.9  5.9  21.3  14.5  29.094310
# 38  0.609  27.3  13.5  35.8  7.0  23.8  11.5  22.960000
# 39  0.611  26.6  15.2  29.3  8.3  17.7  11.1  21.220000
# 40  0.627  30.4  15.0  33.7  6.3  19.3  14.1  28.760000

# %%
# Import Tune Squad player names.
ts_name_df = pd.read_csv('tune_squad.csv', sep='\t')
ts_name_df
# Out:
#     ID              player
# 0   31           Sylvester
# 1   32  Marvin the Martian
# 2   33         Road Runner
# 3   34     Foghorn Leghorn
# 4   35          Bugs Bunny
# 5   36          Elmer Fudd
# 6   37          Lola Bunny
# 7   38           Porky Pig
# 8   39     Tasmanian Devil
# 9   40        Yosemite Sam
# 10  41            Gossamer
# 11  42              Granny
# 12  43      Wile E. Coyote
# 13  44              Tweety
# 14  45            Penelope
# 15  46          Daffy Duck

# %%
# Merge the two DataFrames.
ts_df = pd.merge(ts_df, ts_name_df, on='ID', how='left', suffixes=('_type', '_name'))
ts_df.head()
# Out:
#    ID  player_type  points  possessions  team_pace         GP        MPG  \
# 0  31  tune_squad1  2049.0       1434.0      110.0  64.000000  38.800000
# 1  32  tune_squad2  1795.0       1481.8      112.1  62.000000  35.400000
# 2  33  tune_squad3  1805.0       1509.9      108.6  64.000000  35.400000
# 3  34  tune_squad4  1743.0       1422.4      112.9  64.000000  36.300000
# 4  35  tune_squad5  1963.0       1539.1      117.4  59.771429  35.208333
#
#      TS%   AST    TO   USG  ORR   DRR  REBR        PER         player_name
# 0  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000           Sylvester
# 1  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000  Marvin the Martian
# 2  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000         Road Runner
# 3  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138     Foghorn Leghorn
# 4  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000          Bugs Bunny

# %%
# Rearrange the columns to put the ID and player_name columns next to each other.
column_list = list(ts_df)

player_name = column_list.pop()
column_list[1] = player_name

ts_df = ts_df[column_list]
ts_df.head()
# Out:
#    ID         player_name  points  possessions  team_pace         GP  \
# 0  31           Sylvester  2049.0       1434.0      110.0  64.000000
# 1  32  Marvin the Martian  1795.0       1481.8      112.1  62.000000
# 2  33         Road Runner  1805.0       1509.9      108.6  64.000000
# 3  34     Foghorn Leghorn  1743.0       1422.4      112.9  64.000000
# 4  35          Bugs Bunny  1963.0       1539.1      117.4  59.771429
#
#          MPG    TS%   AST    TO   USG  ORR   DRR  REBR        PER
# 0  38.800000  0.619  31.5  14.9  35.5  8.3  17.6  12.8  28.440000
# 1  35.400000  0.608  31.9  14.5  32.0  6.5  22.5  12.9  23.340000
# 2  35.400000  0.622  27.9  13.9  36.0  5.9  27.7  12.2  22.410000
# 3  36.300000  0.619  30.9  15.6  34.5  5.9  18.9  14.8  29.853138
# 4  35.208333  0.633  32.3  16.2  34.0  5.9  19.8  13.1  27.160000

# %%
# Create a list of only the column names we're interested in.
game_stat_cols = list(ts_df.iloc[:, 7:-1])
game_stat_stdevs = []

# Create a list of standard deviations for each stat.
for stat in game_stat_cols:
    game_stat_stdevs.append(ts_df[stat].std())

# Create a Series of the standard deviations, with the stat names as the index.
stdev_s = pd.Series(game_stat_stdevs, index=game_stat_cols)
stdev_s
# Out:
# TS%     0.008262
# AST     2.140494
# TO      0.797197
# USG     1.892718
# ORR     1.139465
# DRR     3.017962
# REBR    1.802564
# dtype: float64

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.2-cp36-cp36m-win32.whl (6.1 MB)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.5.4-cp36-cp36m-win32.whl (28.3 MB)
# Collecting joblib>=0.11
#   Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (from scikit-learn) (1.19.5)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.1.1 scikit-learn-0.24.2 scipy-1.5.4 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kacpe\downloads\space-jam-anl\.venv\lib\site-packages (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the models and libraries we need.
from sklearn.linear_model import LinearRegression
from numpy.random import randn

# Get the dependent and independent variables for modeling the PER.
X = player_df_final.iloc[:, 7:-1].to_numpy()
y = player_df_final.iloc[:, -1]

# %%
# Define and fit the model.
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
# Print the player with the highest and lower PER for each iteration.
print('Iteration # \thigh PER \tlow PER')

# Run the simulation 10 times.
for i in range(10):

    # Define an empty temporary DataFrame for each iteration.
    # The columns of this DataFrame are the player stats and the index is the players' names.
    game_df = pd.DataFrame(columns=game_stat_cols, index=list(ts_df['player_name']))
    
    # Loop through each stat.
    for stat in game_stat_cols:
        
        # Each player's stats are used to generate a random value for each iteration.
        game_df[stat] = list(ts_df[stat] + randn(len(ts_df)) * stdev_s[stat])
    
    # Use the fitted model to predict players' PERs based on the randomized data.
    game_df['PER'] = lin_reg.predict(game_df)

    # Print the player with the highest and lower PER for each iteration.
    print('Iteration {}'.format(i+1) + ' \t' + game_df['PER'].idxmax() + ' \t' + game_df['PER'].idxmin())
# Out:
# Iteration # 	high PER 	low PER
# Iteration 1 	Wile E. Coyote 	Marvin the Martian
# Iteration 2 	Lola Bunny 	Tweety
# Iteration 3 	Lola Bunny 	Penelope
# Iteration 4 	Gossamer 	Penelope
# Iteration 5 	Lola Bunny 	Daffy Duck
# Iteration 6 	Lola Bunny 	Penelope
# Iteration 7 	Wile E. Coyote 	Penelope
# Iteration 8 	Sylvester 	Road Runner
# Iteration 9 	Lola Bunny 	Tasmanian Devil
# Iteration 10 	Elmer Fudd 	Tasmanian Devil

# %%
# Initialize four empty DataFrames, one for each 12-minute period.
number_of_iterations = 4
df_list = [pd.DataFrame(columns=game_stat_cols, index=list(ts_df['player_name'])) for i in range(number_of_iterations)]

# For each period, generate randomized player data and predict the PER.
# Use the model fitted earlier.
for df in df_list:
    for stat in game_stat_cols:
        df[stat] = list(ts_df[stat] + randn(len(ts_df)) * stdev_s[stat])
    df['PER'] = lin_reg.predict(df)

# Concatenate the DataFrames and make the players' names the index.
game_df = pd.concat(df_list)
game_df.rename_axis('player_name', inplace=True)

# Create another index for the period in question.
minutes = [(x // len(ts_df)) * 12 for x in range(len(game_df))]
game_df['minutes'] = minutes
game_df.set_index('minutes', append=True, inplace=True)
game_df = game_df.swaplevel()

game_df
# Out:
#                                  TS%        AST         TO        USG  \
# minutes player_name
# 0       Sylvester           0.621887  30.527296  16.007559  36.299172
#         Marvin the Martian  0.608300  33.967558  14.595821  30.898487
#         Road Runner         0.626277  22.932448  13.750651  35.433405
#         Foghorn Leghorn     0.618367  30.423535  15.574958  35.942972
#         Bugs Bunny          0.617854  34.273898  17.411658  34.311126
#         Elmer Fudd          0.633271  31.709472  14.825953  36.928429
#         Lola Bunny          0.647359  34.630919  13.601745  36.666701
#         Porky Pig           0.623644  29.512240  16.221638  38.620242
#         Tasmanian Devil     0.600649  26.804312  14.521852  36.408553
#         Gossamer            0.623460  31.889194  15.740471  32.863109
#         Granny              0.612583  28.757645  12.970047  35.544164
#         Wile E. Coyote      0.620669  35.876888  12.951834  37.099793
#         Tweety              0.611323  24.412288  11.048980  36.106002
#         Penelope            0.612093  25.937624  14.211841  28.786705
#         Daffy Duck          0.609438  29.389015  15.358691  33.590412
# 12      Sylvester           0.622139  29.925898  15.219071  34.353268
#         Marvin the Martian  0.616897  31.670256  15.859708  32.662138
#         Road Runner         0.618729  27.303715  13.192070  32.124757
